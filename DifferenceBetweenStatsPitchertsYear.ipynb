# %%
from operator import index
import pandas as pd

def groupby_avg_percentage_year(df, category1, list):

    for i in range (len(list)):
        df[list[i]] = pd.to_numeric(df[list[i]].str.replace("%", ""), errors='coerce')
        df[list[i]] = df[list[i]].astype(float)
        res = df.groupby([category1], sort=False)[list[i]].mean().reset_index()
        res.sort_values(by=[category1], inplace=True)
        res.to_csv("./data/exported/Groupby{0}22.csv".format(list[i]), index=False)
    return (df, res)


def groupby_avg_numeric_year(df, category1, list):

    for i in range (len(list)):
        df[list[i]] = df[list[i]].astype(float)
        res = df.groupby([category1], sort=False)[list[i]].mean().reset_index()
        res.sort_values(by=[category1], inplace=True)
        res.to_csv("./data/exported/Groupby{0}22.csv".format(list[i]), index=False)
    return (df, res)


# Relievers pitch value stats
filename = './data/Pitch Value/Pitch Value_2022.csv'
df = pd.read_csv(filename)
df = df[["Name", "Team", "CSW%", "F-Strike%"]]
df.loc[(df["Name"]=="Luis Castillo") & (df["Team"]=="DET"), "Name"] = "Luis Castillo (DET)"
df.loc[(df["Name"]=="Luis Garcia") & (df["Team"]=="SDP"), "Name"] = "Luis Garcia (SDP)"
df.loc[(df["Name"]=="Luis Ortiz") & (df["Team"]=="SFG"), "Name"] = "Luis Ortiz (SFG)"
df.loc[(df["Name"]=="Diego Castillo") & (df["Team"]=="PIT"), "Name"] = "Diego Castillo (PIT)"
list = ["CSW%", "F-Strike%"]
df, res = groupby_avg_percentage_year(df, "Name", list)

# Relievers win stats
filename = './data/Win Probability/Win Probability_2022.csv'
df = pd.read_csv(filename)
df = df[["Name", "Team", "RE24"]]
df.loc[(df["Name"]=="Luis Castillo") & (df["Team"]=="DET"), "Name"] = "Luis Castillo (DET)"
df.loc[(df["Name"]=="Luis Garcia") & (df["Team"]=="SDP"), "Name"] = "Luis Garcia (SDP)"
df.loc[(df["Name"]=="Luis Ortiz") & (df["Team"]=="SFG"), "Name"] = "Luis Ortiz (SFG)"
df.loc[(df["Name"]=="Diego Castillo") & (df["Team"]=="PIT"), "Name"] = "Diego Castillo (PIT)"
list = ['RE24']
df, res = groupby_avg_numeric_year(df, "Name", list)

# Starter dashboard advanced
filename = './data/Advanced/Advanced_2022.csv'
df = pd.read_csv(filename)
df = df[["Name", "Team", "K-BB%"]]
df.loc[(df["Name"]=="Luis Castillo") & (df["Team"]=="DET"), "Name"] = "Luis Castillo (DET)"
df.loc[(df["Name"]=="Luis Garcia") & (df["Team"]=="SDP"), "Name"] = "Luis Garcia (SDP)"
df.loc[(df["Name"]=="Luis Ortiz") & (df["Team"]=="SFG"), "Name"] = "Luis Ortiz (SFG)"
df.loc[(df["Name"]=="Diego Castillo") & (df["Team"]=="PIT"), "Name"] = "Diego Castillo (PIT)"
list = ['K-BB%']
df, res = groupby_avg_percentage_year(df, "Name", list)

# Starter dashboard dashboard
filename = './data/Dashboard/Dashboard_2022.csv'
df = pd.read_csv(filename)
df = df[["Name", "Team", "WAR"]]
df.loc[(df["Name"]=="Luis Castillo") & (df["Team"]=="DET"), "Name"] = "Luis Castillo (DET)"
df.loc[(df["Name"]=="Luis Garcia") & (df["Team"]=="SDP"), "Name"] = "Luis Garcia (SDP)"
df.loc[(df["Name"]=="Luis Ortiz") & (df["Team"]=="SFG"), "Name"] = "Luis Ortiz (SFG)"
df.loc[(df["Name"]=="Diego Castillo") & (df["Team"]=="PIT"), "Name"] = "Diego Castillo (PIT)"
list = ['WAR']
df, res = groupby_avg_numeric_year(df, "Name", list)

# %%
path = "./data/Exported/"
file1 = "GroupbyCSW%22.csv"
file2 = "GroupbyF-Strike%22.csv"
file3 = "GroupbyRE2422.csv"
file4 = "GroupbyWAR22.csv"
file5 = "GroupbyK-BB%22.csv"

df1 = pd.read_csv(path + file1)
df2 = pd.read_csv(path + file2)
df3 = pd.read_csv(path + file3)
df4 = pd.read_csv(path + file4)
df5 = pd.read_csv(path + file5)

df1 = df1[['Name','CSW%']]
df2 = df2[['Name','F-Strike%']]
df3 = df3[['Name','RE24']]
df4 = df4[['Name','WAR']]
df5 = df5[['Name','K-BB%']]


df_join = pd.merge(df1, df2,  how='left', on=['Name'])
df_join = pd.merge(df_join, df3, how='left', on=["Name"])
df_join = pd.merge(df_join, df4, how='left', on=["Name"])
df_join = pd.merge(df_join, df5, how='left', on=["Name"])

df6 = pd.read_csv("./data/pichertsGS3.csv")
#df_join = df_join[['Name','CSW%','F-Strike%','RE24','WAR','K-BB%']]
df6 = df6[['Name','Type','NewTeamoffSeason21']]
df_join = pd.merge(df_join, df6, how='left', on=["Name"])
df_join['Year'] = '2022'

# shift column 'Name' to first position
first_column = df_join.pop('NewTeamoffSeason21')
  
# insert column using insert(position,column_name,
# first_column) function
df_join.insert(1, 'New team offseason 21', first_column)

df_join.to_csv("./data/Exported/PichertStats22.csv", index=False)

# %%
df1 = pd.read_csv("./data/Exported/PichertStats21.csv")
df2 = pd.read_csv("./data/Exported/PichertStats22.csv")

df = pd.concat([df1, df2], ignore_index=True)
df.sort_values(by=['Name'], inplace=True)
df.to_csv("./data/Exported/PichertsStatsYear.csv", index=False)
df.head()
# Out:
#             Name New team offseason 21       CSW%  F-Strike%      RE24  \
# 0     A.J. Alexy                    No  21.700000  55.000000  0.360000
# 907   A.J. Alexy                    No  25.200000  60.200000 -1.360000
# 1      A.J. Cole                   NaN  25.400000  53.300000  2.670000
# 908  A.J. Ladwig                    No  17.100000  80.000000 -1.640000
# 2    A.J. Minter                    No  30.816667  63.383333  1.216667
#
#           WAR      K-BB%      Type  Year
# 0    0.000000   2.150000  Reliever  2021
# 907 -0.066667  -6.533333  Reliever  2022
# 1    0.100000  20.000000       NaN  2021
# 908 -0.200000   0.000000  Reliever  2022
# 2    0.183333  16.900000  Reliever  2021

# %%
import pandas as pd

filename = './data/Exported/PichertsStatsYear.csv'
#starter_list = ["Average of WAR", "Average of K-BB%", "Average of CSW%"]
#reliever_list = ['CSW%','F-Strike%','RE24']
list2 = ['CSW%','F-Strike%','RE24', 'WAR', 'K-BB%']
output_name = "PichertsStatsYear"
index = "Name"

def difference(filename ,index, list):
     
     df = pd.read_csv(filename)
     df = df.set_index(index)
     for i in range (len(list)):
          df[list[i]+"Diff"] = (df[list[i]]-
               df.groupby(index)[list[i]].last()).to_numpy()

          df[list[i]+"Diff"] = -df[list[i]+"Diff"]
          df[list[i]+"Diff"] = df[list[i]+"Diff"].shift(+1)
     return df

df = difference(filename, index, list2)
df.to_csv('./data/Exported/Difference{0}.csv'.format(output_name))
